# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# %cd gdrive/
# Out:
# /content/gdrive

# %%
# !ls
# Out:
# MyDrive  Othercomputers

# %%
# %cd MyDrive/Colab\ Notebooks/
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
# !ls
# Out:
#  ConvNetsTransferLearning				    DL_Week_2.ipynb
# 'Copy of CS224W_Colab_0.ipynb'				    Untitled.pages
# 'Copy of The Annotated "Attention is All You Need".ipynb'   Yosemite_demo.ipynb
# 'Copy of Yosemite_demo.ipynb'				    yos.jpg
